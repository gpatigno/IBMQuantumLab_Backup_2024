# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg = QuantumRegister(3, 'q')
creg = ClassicalRegister(3, 'c')
circuit = QuantumCircuit(qreg, creg)

circuit.reset(qreg[0])
circuit.reset(qreg[1])
circuit.reset(qreg[2])

circuit.barrier(qreg[0], qreg[1], qreg[2])
circuit.h(qreg[0])
circuit.h(qreg[2])

circuit.barrier(qreg[0], qreg[1], qreg[2])
circuit.ry(pi / 4, qreg[0])
circuit.ry(3 * pi / 2, qreg[2])

circuit.barrier(qreg[0], qreg[1], qreg[2])
circuit.x(qreg[1])
circuit.ccx(qreg[1], qreg[0], qreg[2])

circuit.barrier(qreg[0], qreg[1], qreg[2])
circuit.measure(qreg[0], creg[0])
circuit.measure(qreg[1], creg[1])
circuit.measure(qreg[2], creg[2])

# %%
circuit.draw('mpl')
